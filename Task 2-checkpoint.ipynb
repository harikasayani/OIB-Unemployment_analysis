# %% [markdown]
# # Importing Libraries

# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import seaborn as sns

# %% [markdown]
# # Loading data set

# %%
df=pd.read_csv('D:\Documents\Data Sets\Data_for_Unemployment_in_India.csv')
df=pd.read_csv('D:\Documents\Data Sets\Data_for_Unemployment_Rate_upto_11_2020.csv')

# %%
df.head(5)
# Out:
#            Region         Date  Frequency   Estimated Unemployment Rate (%)  \
# 0  Andhra Pradesh   31-01-2020          M                              5.48
# 1  Andhra Pradesh   29-02-2020          M                              5.83
# 2  Andhra Pradesh   31-03-2020          M                              5.79
# 3  Andhra Pradesh   30-04-2020          M                             20.51
# 4  Andhra Pradesh   31-05-2020          M                             17.43
#
#     Estimated Employed   Estimated Labour Participation Rate (%) Region.1  \
# 0             16635535                                     41.02    South
# 1             16545652                                     40.90    South
# 2             15881197                                     39.18    South
# 3             11336911                                     33.10    South
# 4             12988845                                     36.46    South
#
#    longitude  latitude
# 0    15.9129     79.74
# ...

# %% [markdown]
# # Information about dataset

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 267 entries, 0 to 266
# Data columns (total 9 columns):
#  #   Column                                    Non-Null Count  Dtype
# ---  ------                                    --------------  -----
#  0   Region                                    267 non-null    object
#  1    Date                                     267 non-null    object
#  2    Frequency                                267 non-null    object
#  3    Estimated Unemployment Rate (%)          267 non-null    float64
#  4    Estimated Employed                       267 non-null    int64
#  5    Estimated Labour Participation Rate (%)  267 non-null    float64
#  6   Region.1                                  267 non-null    object
#  7   longitude                                 267 non-null    float64
#  8   latitude                                  267 non-null    float64
# dtypes: float64(4), int64(1), object(4)
# memory usage: 18.9+ KB

# %%
df.shape
# Out:
# (267, 9)

# %%
df.isnull().sum()
# Out:
# Region                                      0
#  Date                                       0
#  Frequency                                  0
#  Estimated Unemployment Rate (%)            0
#  Estimated Employed                         0
#  Estimated Labour Participation Rate (%)    0
# Region.1                                    0
# longitude                                   0
# latitude                                    0
# dtype: int64

# %%
df.describe()
# Out:
#         Estimated Unemployment Rate (%)   Estimated Employed  \
# count                        267.000000         2.670000e+02
# mean                          12.236929         1.396211e+07
# std                           10.803283         1.336632e+07
# min                            0.500000         1.175420e+05
# 25%                            4.845000         2.838930e+06
# 50%                            9.650000         9.732417e+06
# 75%                           16.755000         2.187869e+07
# max                           75.850000         5.943376e+07
#
#         Estimated Labour Participation Rate (%)   longitude    latitude
# count                                267.000000  267.000000  267.000000
# mean                                  41.681573   22.826048   80.532425
# std                                    7.845419    6.270731    5.831738
# min                                   16.770000   10.850500   71.192400
# ...

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.columns
# Out:
# Index(['Region', ' Date', ' Frequency', ' Estimated Unemployment Rate (%)',
#        ' Estimated Employed', ' Estimated Labour Participation Rate (%)',
#        'Region.1', 'longitude', 'latitude'],
#       dtype='object')

# %% [markdown]
# # Visualizing the data

# %%
plt.title('Region wise employed estimation')
sns.histplot(x=" Estimated Employed",hue="Region.1",data=df)
plt.show()

# %%
plt.title('Region wise unemployment estimation')
sns.histplot(x=" Estimated Unemployment Rate (%)",hue="Region.1",data=df)
plt.show()

# %%
plt.title('Region wise employed estimation')
sns.boxplot(orient='h',data=df,x=" Estimated Employed",y="Region.1")
plt.show()

# %%
plt.title('Region wise unemployment estimation')
sns.boxplot(orient='v',data=df,y=" Estimated Unemployment Rate (%)",x="Region.1")
plt.show()

# %%
df['Month']=pd.to_datetime(data1[' Date']).dt.month
df['Month'].unique()
sns.catplot(x="Month",y=" Estimated Employed",kind="violin",data=df)
plt.show()
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_10300\2684842366.py:1: UserWarning: Parsing dates in  %d-%m-%Y format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   df['Month']=pd.to_datetime(data1[' Date']).dt.month
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
df['Month']=pd.to_datetime(data1[' Date']).dt.month
df['Month'].unique()
sns.catplot(x="Month",y=" Estimated Unemployment Rate (%)",kind="violin",data=df)
plt.show()
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_10300\2846223529.py:1: UserWarning: Parsing dates in  %d-%m-%Y format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   df['Month']=pd.to_datetime(data1[' Date']).dt.month
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
plt.title('Estimating employment rate monthly')
sns.barplot(data=df,x="Month",y=" Estimated Employed")
plt.show()

# %%
plt.title('Estimating unemployment rate monthly')
sns.barplot(data=df,x="Month",y=" Estimated Unemployment Rate (%)")
plt.show()
